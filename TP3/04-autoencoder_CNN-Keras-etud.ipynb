# %% [markdown]
# # Autoencodeur
#
# Objectif : construire un autoencodeur à deux couches en utilisant Keras :
# - l'encodeur compresse l'information dans l'espace latent
# - le décodeur reconstruit l'image

# %% [markdown]
# ## MNIST
#
# La base de données MNIST (Mixed National Institute of Standards and Technology), est une base de données de chiffres manuscrits. C’est une base de données standard pour le test de nouveaux algorithmes de reconnaissance de ces chiffres. Elle est composée de 60000 images d’apprentissage et 10000 images de test. Les images en noir et blanc, normalisées centrées de 28 pixels de côté.
#
# ![mnist.png](./mnist.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow.keras as tk
from tensorflow.keras.datasets import mnist

from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam

# %% [markdown]
# On charge ensuite les données MNIST. Les paramètres de la base sont récupérés (nombre d'exemples, de classes, taille de la rétine).

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()


num_examples = x_train.shape[0] 
num_test = x_test.shape[0]
num_input = x_train.shape[1]*x_train.shape[2]
num_classes = 10

img_size = x_train.shape[1] 
img_shape = (img_size, img_size)


# normalisation
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %% [markdown]
# ## Autoencodeur à couches convolutives

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import  Input,Conv2D,MaxPool2D,Dense,BatchNormalization,LeakyReLU,Flatten, Reshape,Conv2DTranspose

dim_latent = 128
batch_size=256

# Encodeur
#TODO

# Decodeur
#TODO

# AE
#TODO

# %%
model.compile(optimizer=Adam(1e-3), loss='binary_crossentropy',metrics=['acc'])
model.summary()
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 28, 28, 32)        128
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# latent (Dense)               (None, 128)               401536
# _________________________________________________________________
# dense_3 (Dense)              (None, 3136)              404544
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 3136)              0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 14, 14, 64)        36928
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 28, 28, 1)         577
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 28, 28, 1)         4
# _________________________________________________________________
# outputs (Activation)         (None, 28, 28, 1)         0
# =================================================================
# Total params: 863,045
# Trainable params: 862,723
# Non-trainable params: 322
# _________________________________________________________________
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 28, 28, 32)        128
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# latent (Dense)               (None, 128)               401536
# _________________________________________________________________
# dense_3 (Dense)              (None, 3136)              404544
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 3136)              0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 7, 7, 64)          0
# =================================================================
# Total params: 825,280
# Trainable params: 825,088
# Non-trainable params: 192
# _________________________________________________________________

# %%
class myCallback(tk.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}): 
        if((epoch-1) % 5==0):   
            print("\nEpoch {0:d} Précision :{1:5.3f} ".format(epoch-1,logs.get('acc') ))
            encoded_imgs = encoder.predict(x_test)
            decoded_imgs = model.predict(x_test)


            n = 8  
            plt.figure(figsize=(40, 4))
            for i in range(n):
                ax = plt.subplot(3, 20, i + 1)
                plt.imshow(x_test[i].reshape(28, 28))
                plt.gray()
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)

                ax = plt.subplot(3, 20, i + 1 + 20)
                plt.imshow(encoded_imgs[i].reshape(16,8))
                plt.gray()
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)

                ax = plt.subplot(3, 20, 2*20 +i+ 1)
                plt.imshow(decoded_imgs[i].reshape(28, 28))
                plt.gray()
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)

            plt.show()

            
callbacks = myCallback()
model.fit(x_train,x_train,epochs=20,batch_size=batch_size,validation_data=(x_test, x_test),callbacks=[callbacks])
# Out:
# Epoch 1/20
# 235/235 [==============================] - 42s 180ms/step - loss: 0.1267 - acc: 0.8155 - val_loss: 0.1221 - val_acc: 0.8145
# Epoch 2/20
# 235/235 [==============================] - ETA: 0s - loss: 0.1172 - acc: 0.8155
# Epoch 0 Précision :0.815
# 235/235 [==============================] - 51s 216ms/step - loss: 0.1172 - acc: 0.8155 - val_loss: 0.1148 - val_acc: 0.8145
# Epoch 3/20
# 235/235 [==============================] - 43s 183ms/step - loss: 0.1095 - acc: 0.8155 - val_loss: 0.1057 - val_acc: 0.8145
# Epoch 4/20
# 235/235 [==============================] - 43s 183ms/step - loss: 0.1033 - acc: 0.8155 - val_loss: 0.1011 - val_acc: 0.8145
# Epoch 5/20
# 235/235 [==============================] - 43s 184ms/step - loss: 0.0982 - acc: 0.8155 - val_loss: 0.0976 - val_acc: 0.8145
# Epoch 6/20
# 235/235 [==============================] - 43s 182ms/step - loss: 0.0939 - acc: 0.8155 - val_loss: 0.0907 - val_acc: 0.8145
# Epoch 7/20
# 235/235 [==============================] - ETA: 0s - loss: 0.0903 - acc: 0.8155
# Epoch 5 Précision :0.815
# 235/235 [==============================] - 50s 211ms/step - loss: 0.0903 - acc: 0.8155 - val_loss: 0.0915 - val_acc: 0.8145
# Epoch 8/20
# 235/235 [==============================] - 45s 192ms/step - loss: 0.0872 - acc: 0.8155 - val_loss: 0.0875 - val_acc: 0.8145
# Epoch 9/20
# 235/235 [==============================] - 44s 186ms/step - loss: 0.0845 - acc: 0.8155 - val_loss: 0.0829 - val_acc: 0.8145
# Epoch 10/20
# 235/235 [==============================] - 44s 187ms/step - loss: 0.0822 - acc: 0.8155 - val_loss: 0.0810 - val_acc: 0.8145
# Epoch 11/20
# 235/235 [==============================] - 44s 189ms/step - loss: 0.0802 - acc: 0.8155 - val_loss: 0.0790 - val_acc: 0.8145
# Epoch 12/20
# 235/235 [==============================] - ETA: 0s - loss: 0.0785 - acc: 0.8155
# Epoch 10 Précision :0.815
# 235/235 [==============================] - 50s 214ms/step - loss: 0.0785 - acc: 0.8155 - val_loss: 0.0779 - val_acc: 0.8145
# Epoch 13/20
# 235/235 [==============================] - 44s 188ms/step - loss: 0.0770 - acc: 0.8155 - val_loss: 0.0761 - val_acc: 0.8145
# Epoch 14/20
# 235/235 [==============================] - 47s 199ms/step - loss: 0.0755 - acc: 0.8155 - val_loss: 0.0746 - val_acc: 0.8145
# Epoch 15/20
# 235/235 [==============================] - 44s 188ms/step - loss: 0.0743 - acc: 0.8155 - val_loss: 0.0741 - val_acc: 0.8145
# Epoch 16/20
# 235/235 [==============================] - 43s 185ms/step - loss: 0.0732 - acc: 0.8155 - val_loss: 0.0732 - val_acc: 0.8145
# Epoch 17/20
# 235/235 [==============================] - ETA: 0s - loss: 0.0722 - acc: 0.8155
# Epoch 15 Précision :0.815
# 235/235 [==============================] - 53s 224ms/step - loss: 0.0722 - acc: 0.8155 - val_loss: 0.0717 - val_acc: 0.8145
# Epoch 18/20
# 235/235 [==============================] - 45s 193ms/step - loss: 0.0713 - acc: 0.8155 - val_loss: 0.0706 - val_acc: 0.8145
# Epoch 19/20
# 235/235 [==============================] - 50s 211ms/step - loss: 0.0705 - acc: 0.8155 - val_loss: 0.0697 - val_acc: 0.8145
# Epoch 20/20
# 235/235 [==============================] - 45s 190ms/step - loss: 0.0697 - acc: 0.8155 - val_loss: 0.0695 - val_acc: 0.8145
